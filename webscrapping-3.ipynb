# %%
from bs4 import BeautifulSoup
import requests

# %%
# Function to extract Product Title
def get_title(soup):
     
    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
 
        # Inner NavigableString Object
        title_value = title.string
 
        # Title as a string value
        title_string = title_value.strip()
        # # Printing types of values for efficient understanding
        # print(type(title))
        # print(type(title_value))
        # print(type(title_string))
        # print()
 
    except AttributeError:
        title_string = ""   
 
    return title_string
 
# Function to extract Product Price
def get_price(soup):
 
    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()
 
    except AttributeError:
        price = ""  
 
    return price
 
# Function to extract Product Rating
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
 
# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""
        return review_count
 
# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
 
    except AttributeError:
        available = ""  
 
    return available    
 
if __name__ == '__main__':
    # Headers for request
    HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
                'Accept-Language': 'en-US, en;q=0.5'})
 
    # The webpage URL
    URL = "https://www.amazon.com/Sony-PlayStation-Pro-1TB-Console-4/dp/B07K14XKZH/"
 
    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)
 
    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "lxml")
 
    # Function calls to display all necessary product information
    print("Product Title =", get_title(soup))
    print("Product Price =", get_price(soup))
    print("Product Rating =", get_rating(soup))
    print("Number of Product Reviews =", get_review_count(soup))
    print("Availability =", get_availability(soup))
    print()
    print()
# Out:
# Product Title = Sony PlayStation 4 Pro 1TB Console - Black (PS4 Pro)
# Product Price = $661.79
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = None
# Availability = In Stock.

# %%
#extract product details across multiple webpages

# Function to extract Product Title
def get_title(soup):
     
    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
 
        # Inner NavigatableString Object
        title_value = title.string
 
        # Title as a string value
        title_string = title_value.strip()
        # # Printing types of values for efficient understanding
        # print(type(title))
        # print(type(title_value))
        # print(type(title_string))
        # print()
 
    except AttributeError:
        title_string = ""   
 
    return title_string
 
# Function to extract Product Price
def get_price(soup):
 
    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()
 
    except AttributeError:
 
        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()
 
        except:     
            price = ""  
 
    return price
 
# Function to extract Product Rating
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
 
# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""   
 
    return review_count
 
# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
 
    except AttributeError:
        available = "Not Available"
 
    return available    
 
 
if __name__ == '__main__':
 
    # Headers for request
    HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
                'Accept-Language': 'en-US'})
 
    # The webpage URL
    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"
     
    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)
 
    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "lxml")
 
    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
 
    # Store the links
    links_list = []
 
    # Loop for extracting links from Tag Objects
    for link in links:
        links_list.append(link.get('href'))
 
 
    # Loop for extracting product details from each link 
    for link in links_list:
 
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)
 
        new_soup = BeautifulSoup(new_webpage.content, "lxml")
         
        # Function calls to display all necessary product information
        print("Product Title =", get_title(new_soup))
        print("Product Price =", get_price(new_soup))
        print("Product Rating =", get_rating(new_soup))
        print("Number of Product Reviews =", get_review_count(new_soup))
        print("Availability =", get_availability(new_soup))
        print()
        print()
# Out:
# Product Title = SONY PlayStation 4 Slim 1TB Console, Light & Slim PS4 System, 1TB Hard Drive, All the Greatest Games, TV, Music & More
# Product Price = $389.00
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 629 ratings
# Availability = Only 7 left in stock - order soon.
#
#
# Product Title = 2 Pack-Game Controller for PS4,Wireless Controller for Playstation 4 with Dual Vibration Game Joystick (Transparent White and Transparent Blue)
# Product Price = $50.99
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 1,623 ratings
# Availability = Not Available
#
#
# Product Title = DualShock 4 Wireless Controller for PlayStation 4 - Jet Black
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 93,143 ratings
# Availability = In Stock.
#
#
# Product Title = Wireless Bluetooth Controller for PS4 - Magma Red Playstation 4 Gamepad with Dual Shock Double Vibration 6-Axis Gyro Touch Panel, Designed for PS4/PS4 Slim/Pro, Compatible with Windows PC Android
# Product Price = $29.99
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 2,527 ratings
# Availability = Not Available
#
#
# Product Title = 2020 Sony Playstation 4 1TB Slim Console Bundle with Marvel's Spider-Man: Game of The Year Disk Edition + VGSION HDMI Cable
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 28 ratings
# Availability = Only 2 left in stock - order soon.
#
#
# Product Title = PowerA USB Charging Cable for PlayStation 4
# Product Price = $6.99
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 27,883 ratings
# Availability = In Stock.
#
#
# Product Title = PS4 Controller Wireless,LITTJOY for Playstation 4 Controller,Compatible with PS4/Slim/Pro Console (forest green)
# Product Price = $36.98
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 7 ratings
# Availability = In Stock.
#
#
# Product Title = BlueFire Professional 3.5mm PS4 Gaming Headset Headphone with Mic and LED Lights for Playstation 4, Xbox one,Laptop, Computer (Blue)
# Product Price = $19.99
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 5,915 ratings
# Availability = Not Available
#
#
# Product Title = HyperX ChargePlay Duo - Controller Charging Station for Playstation 4, Charges Two DUALSHOCK 4 Controllers via The Ext Port
# Product Price = $24.31
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 690 ratings
# Availability = In Stock.
#
#
# Product Title = LITTJOY For PS4 Controller, Wireless Controller for Playstation 4,with Dual Vibration/Stereo Headset Jack/Touch Pad / Six-axis Motion Control,Compatible with PS4/Slim/Pro Console
# Product Price = $36.98
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 407 ratings
# Availability = Not Available
#
#
# Product Title = BEBONCOOL PS4 Controller Charger, Controller USB Charging Station Dock for DualShock 4, PlayStation 4 Charging Station for Sony Playstation4 / PS4 / PS4 Slim / PS4 Pro Controller-Black
# Product Price = $14.99
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 34,845 ratings
# Availability = Not Available
#
#
# Product Title = Turtle Beach Recon 70 White Gaming Headset for PlayStation 5, PS4 Pro, PS4, Xbox One & Xbox Series X|S, Nintendo Switch, PC, and Mobile
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 46,548 ratings
# Availability = Not Available
#
#
# Product Title = PS4 Controller, Kydlan Wireless Game Controller for PS4 Pro/Playstation 4/PS4 Slim , Modded PS4 Remote Gamepad with Dual Shock, Audio Function, Motion Control for Playstation 4
# Product Price = $29.99
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 41 ratings
# Availability = Not Available
#
#
# Product Title = PS4 Controller Charger, PS4 Charging Station with Dual Charging Port, PS4 Controller Charger Station for Playstation 4/PS4/PS4 Slim/PS4 Pro Controller, Upgrade USB C Cable＆Separate PS4 Micro Receivers
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 3,719 ratings
# Availability = Not Available
#
#
# Product Title = $100 PlayStation Store Gift Card [Digital Code]
# Product Price = $100.00
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 138,102 ratings
# Availability = Available now.
#
#
# Product Title = Holiday Ultimate Bundle Playstation 4 1TB Slim w/bonus Marvel's Spider-Man: Game of The Year Edition
# Product Price = $479.80
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 760 ratings
# Availability = Only 9 left in stock - order soon.
#
#
# Product Title = Wireless Controller for PS4 RegeMoudal Wireless Controller for PS4/Pro/Slim, Touch Panel Gamepad with Double Vibration and Audio Function
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 258 ratings
# Availability = Not Available
#
#
# Product Title = PS4 Vertical Stand Cooling Fan for PS4 Slim/ PS4 Pro/ Regular PlayStation4, PS4 Stand Controller Charger Station for Dual Charging, PS4 Accesossries with Game Storage for Playstation Consoles
# Product Price = $22.99
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 393 ratings
# Availability = Not Available
#
#
# Product Title = PS4 Controller Charger Charging Cable 10ft 2 Pack, Charge and Play, Extra Long Micro USB 2.0 High Speed Sync Cord for Playstation 4/ DualShock 4/ PS4 Slim/ PS4 Pro/Xbox One/Xbox One S/Xb
# Product Price = $8.96
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 589 ratings
# Availability = Not Available
#
#
# Product Title = [2021 Edition] TopACE for PS4 Controller, Wireless Controller for Playstation 4/Pro/3/Slim/PC, HD Dual Vibration, Headphone Touch Panel Gamepad, Mini LED Indicator
# Product Price = $36.99
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 1,155 ratings
# Availability = Not Available
#
#
# Product Title = PS4 Controller Wireless Gamepad for Playstation 4, Dual Shock Remote for Sony Playstation 4 Control with Touch Panel Compatible Witch PS4 / PS4 Pro / PS4 Slim (Blue)
# Product Price = $20.68
# Product Rating = 3.5 out of 5 stars
# Number of Product Reviews = 158 ratings
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4 Stars & Up
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4 Stars & Up
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4 Stars & Up
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4 Stars & Up
# Number of Product Reviews =
# Availability = Not Available

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "BEST Python Course"
  
for j in search(query, tld="co.in", num=10, stop=10, pause=2): 
    print(j)
# Out:
# https://hackr.io/blog/best-python-courses
# https://medium.com/better-programming/top-5-courses-to-learn-python-in-2018-best-of-lot-26644a99e7ec
# https://www.coursera.org/courses?query=python&page=1
# https://www.stoodnt.com/blog/best-online-courses-python/
# https://www.guru99.com/best-python-courses.html
# https://www.quora.com/What-are-the-best-python-programming-online-courses
# https://www.quora.com/What-is-the-best-python-course
# https://www.quora.com/Which-is-the-best-python-course-on-Udemy-from-scratch-to-professional
# https://www.quora.com/What-is-the-best-Python-course-to-start-with
# https://www.quora.com/What-are-the-best-courses-to-learn-python-in-Udemy
