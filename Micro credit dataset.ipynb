# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import time
from sklearn import metrics
from sklearn import neighbors
from sklearn import ensemble
from sklearn import tree
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from pandas.plotting import scatter_matrix
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
from datetime import datetime, date, time, timedelta
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
import matplotlib.ticker as mtick
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn import svm
plt.style.use('ggplot')

# %%
from sklearn.feature_selection import SelectKBest,mutual_info_classif

# %% [markdown]
# Reading data

# %%
data = pd.read_csv("C:\\Users\\HP\\Desktop\\DT\\Micro Credit Project\\data file.csv")

# %%
data.head(10)
# Out:
#    Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789   272.0   3055.050000   3065.150000
# 1           2      1  76462I70374   712.0  12122.000000  12124.750000
# 2           3      1  17943I70372   535.0   1398.000000   1398.000000
# 3           4      1  55773I70781   241.0     21.228000     21.228000
# 4           5      1  03813I82730   947.0    150.619333    150.619333
# 5           6      1  35819I70783   568.0   2257.362667   2261.460000
# 6           7      1  96759I84459   545.0   2876.641667   2883.970000
# 7           8      1  09832I90846   768.0  12905.000000  17804.150000
# 8           9      1  59772I84450  1191.0     90.695000     90.695000
# 9          10      1  56331I70783   536.0     29.357333     29.357333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da     ...      \
# 0    220.13    260.13                2.0                0.0     ...
# ...

# %% [markdown]
# #Data Exploration

# %%
data=data.drop(data.columns[0], axis=1)
data=data.drop(data.columns[34], axis=1)
data["pdate"] = pd.to_datetime(data["pdate"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 35 columns):
# label                   209593 non-null int64
# msisdn                  209593 non-null object
# aon                     209593 non-null float64
# daily_decr30            209593 non-null float64
# daily_decr90            209593 non-null float64
# rental30                209593 non-null float64
# rental90                209593 non-null float64
# last_rech_date_ma       209593 non-null float64
# last_rech_date_da       209593 non-null float64
# last_rech_amt_ma        209593 non-null int64
# cnt_ma_rech30           209593 non-null int64
# fr_ma_rech30            209593 non-null float64
# sumamnt_ma_rech30       209593 non-null float64
# medianamnt_ma_rech30    209593 non-null float64
# medianmarechprebal30    209593 non-null float64
# cnt_ma_rech90           209593 non-null int64
# fr_ma_rech90            209593 non-null int64
# ...

# %%
data.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
data.isna().sum().plot(kind="bar")
data.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pdate                   0
# dtype: int64

# %%
data.tail(10)
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 209583      1  30201I82732   935.0     15.550667     15.550667    140.44
# 209584      0  70387I89237   945.0      0.000000      0.000000     78.30
# 209585      1  12227I90843   793.0   5350.315333   5356.210000    594.80
# 209586      1  60331I70370   254.0  20079.157333  20228.090000   4003.12
# 209587      1  19900I95200   239.0  14678.000000  14704.900000  12935.26
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 209583    140.44                4.0                0.0              1547
# ...

# %%
len(pd.unique(data["msisdn"]))
# Out:
# 186243

# %%
data.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
data.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-29a79790751a> in <module>()
# ----> 1 data.unique()
#
# ~\Anacondanew\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
col_names=data.columns
col_names
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pdate'],
#       dtype='object')

# %%
data['label'].value_counts()[0]/len(data['label'])
# Out:
# 0.12482287099282896

# %%
data['label'].value_counts()[1]/len(data['label'])
# Out:
# 0.875177129007171

# %% [markdown]
# #Data is skewed with the ration of 12.5/87.5

# %%
#relation between average loan amount and loan status
data[['amnt_loans90','label']].groupby(by='label').mean()

#Loan defaulters tend to apply for larger loans.
# Out:
#        amnt_loans90
# label
# 0          9.642382
# 1         25.642590

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data['amnt_loans90'],data['label'])

# %%
fig,ax=plt.subplots()
ax.boxplot(data["fr_da_rech90"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b03c575908>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b03c589208>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b03c5757b8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b03c589a58>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b03c589e80>],
#  'means': []}

# %%
data["fr_da_rech90"].min()
# Out:
# 0

# %% [markdown]
# data cleaning

# %%
print(sum(data['label']==1))
print(sum(data['label']==0))
len(data.index)
# Out:
# 183431
# 26162
# 209593

# %% [markdown]
# data visualization

# %%
g=sns.factorplot(x="label",data=data,kind="count",palette="PRGn",alpha=1)
g.set(xlabel="Label",ylabel="Count")
plt.show()

# %% [markdown]
# Feature Selection (Logistic Regression)

# %%
Xsel=data.iloc[:,2:40]
Ysel=data.iloc[:,0]

# %%
fit=SelectKBest(score_func=chi2,k="all")

# %%
fit=bestfeatures.fit(Xsel,Ysel)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-80c4a4d614ee> in <module>()
# ----> 1 fit=bestfeatures.fit(Xsel,Ysel)
#
# ~\Anacondanew\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     342         """
#     343         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc'],
# --> 344                                    multi_output=True)
#     345
#     346         if not callable(self.score_func):
#
# ~\Anacondanew\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\Anacondanew\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...
